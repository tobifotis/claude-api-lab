# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Collecting anthropic
#   Downloading anthropic-0.96.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting anyio<5,>=3.5.0 (from anthropic)
#   Downloading anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting distro<2,>=1.7.0 (from anthropic)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting docstring-parser<1,>=0.15 (from anthropic)
#   Downloading docstring_parser-0.18.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting httpx<1,>=0.25.0 (from anthropic)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from anthropic)
#   Downloading jiter-0.14.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from anthropic)
#   Downloading pydantic-2.13.1-py3-none-any.whl.metadata (108 kB)
# Collecting sniffio (from anthropic)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting typing-extensions<5,>=4.14 (from anthropic)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->anthropic)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting certifi (from httpx<1,>=0.25.0->anthropic)
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.25.0->anthropic)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.25.0->anthropic)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->anthropic)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.1 (from pydantic<3,>=1.9.0->anthropic)
#   Downloading pydantic_core-2.46.1-cp313-cp313-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->anthropic)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Downloading anthropic-0.96.0-py3-none-any.whl (635 kB)
#    ---------------------------------------- 0.0/635.9 kB ? eta -:--:--
#    ---------------------------------------- 635.9/635.9 kB 10.6 MB/s  0:00:00
# Downloading anyio-4.13.0-py3-none-any.whl (114 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jiter-0.14.0-cp313-cp313-win_amd64.whl (201 kB)
# Downloading pydantic-2.13.1-py3-none-any.whl (471 kB)
# Downloading pydantic_core-2.46.1-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 24.8 MB/s  0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: typing-extensions, sniffio, python-dotenv, jiter, idna, h11, docstring-parser, distro, certifi, annotated-types, typing-inspection, pydantic-core, httpcore, anyio, pydantic, httpx, anthropic
#
#    ---- -----------------------------------  2/17 [python-dotenv]
#    --------- ------------------------------  4/17 [idna]
#    ----------- ----------------------------  5/17 [h11]
#    -------------- -------------------------  6/17 [docstring-parser]
#    ------------------ ---------------------  8/17 [certifi]
#    ------------------------- -------------- 11/17 [pydantic-core]
#    ---------------------------- ----------- 12/17 [httpcore]
#    ---------------------------- ----------- 12/17 [httpcore]
#    ---------------------------- ----------- 12/17 [httpcore]
#    ------------------------------ --------- 13/17 [anyio]
#    ------------------------------ --------- 13/17 [anyio]
#    ------------------------------ --------- 13/17 [anyio]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    ----------------------------------- ---- 15/17 [httpx]
#    ----------------------------------- ---- 15/17 [httpx]
#    ----------------------------------- ---- 15/17 [httpx]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ------------------------------------- -- 16/17 [anthropic]
#    ---------------------------------------- 17/17 [anthropic]
#
# Successfully installed annotated-types-0.7.0 anthropic-0.96.0 anyio-4.13.0 certifi-2026.2.25 distro-1.9.0 docstring-parser-0.18.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 jiter-0.14.0 pydantic-2.13.1 pydantic-core-2.46.1 python-dotenv-1.2.2 sniffio-1.3.1 typing-extensions-4.15.0 typing-inspection-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# Make a starting list of messages
messages = []

# Add in the initial user question of "Define cloud computing in one concise sentence"
add_user_message(messages, "Define cloud computing in one concise sentence")

# Pass the list of messages into 'chat' to get an answer
answer = chat(messages)

# Take the answer and add it as an assistant message into our list
add_assistant_message(messages, answer)

# Add in the user's follow-up question
add_user_message(messages, "Write another sentence")

# Call chat again with the list of messages to get a final answer
answer = chat(messages)

# Print answer out
answer
# Out:
# 'This allows individuals and organizations to access scalable, flexible resources on demand from anywhere in the world, improving efficiency and reducing IT costs.'
